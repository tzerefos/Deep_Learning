# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt

# %%
df_summary = pd.read_csv("datasets/corona_chest_xray/Chest_xray_Corona_dataset_Summary.csv")
df_metadata = pd.read_csv("datasets/corona_chest_xray/Chest_xray_Corona_Metadata.csv")

# %%
# df_metadata[df_metadata['Label_2_Virus_category']]
display(df_summary)
# print(df_summary['Image_Count'].sum())
# Out:
#    Unnamed: 0     Label Label_1_Virus_category Label_2_Virus_category  \
# 0           0    Normal                    NaN                    NaN
# 1           1  Pnemonia         Stress-Smoking                   ARDS
# 2           2  Pnemonia                  Virus                    NaN
# 3           3  Pnemonia                  Virus               COVID-19
# 4           4  Pnemonia                  Virus                   SARS
# 5           5  Pnemonia               bacteria                    NaN
# 6           6  Pnemonia               bacteria          Streptococcus
#
#    Image_Count
# 0         1576
# 1            2
# 2         1493
# 3           58
# 4            4
# 5         2772
# 6            5

# %%
display(df_metadata)
df_metadata[df_metadata['Label_2_Virus_category'] == 'COVID-19']
display(df_metadata['Label_2_Virus_category'].value_counts())
display(df_metadata['Label_1_Virus_category'].value_counts())
display(df_metadata['Label'].value_counts())
# Out:
#       Unnamed: 0            X_ray_image_name     Label Dataset_type  \
# 0              0           IM-0128-0001.jpeg    Normal        TRAIN
# 1              1           IM-0127-0001.jpeg    Normal        TRAIN
# 2              2           IM-0125-0001.jpeg    Normal        TRAIN
# 3              3           IM-0122-0001.jpeg    Normal        TRAIN
# 4              4           IM-0119-0001.jpeg    Normal        TRAIN
# ...          ...                         ...       ...          ...
# 5905        5928  person1637_virus_2834.jpeg  Pnemonia         TEST
# 5906        5929  person1635_virus_2831.jpeg  Pnemonia         TEST
# 5907        5930  person1634_virus_2830.jpeg  Pnemonia         TEST
# 5908        5931  person1633_virus_2829.jpeg  Pnemonia         TEST
# 5909        5932  person1632_virus_2827.jpeg  Pnemonia         TEST
#
#      Label_2_Virus_category Label_1_Virus_category
# 0                       NaN                    NaN
# ...

# %%
display(df_covid)
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Label, Label_1_Virus_category, Label_2_Virus_category, Image_Count]
# Index: []
